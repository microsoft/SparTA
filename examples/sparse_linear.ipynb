# %% [markdown]
# ### Sparse Linear Operator
# This is an example of how to create and tune a sparse linear operator.

# %%
import torch
import matplotlib.pyplot as plt
import sparta

# %% [markdown]
# First, we need to create a PyTorch dense linear operator. Suppose the input feature number is K, the output feature number is N and the batch size is M.
#
# Note that the optimal implementation and configuration are different for different batch sizes, so we need to determine the batch size at the very early stage.

# %%
M, K, N = 4096, 3072, 768
dense_linear = torch.nn.Linear(K, N).cuda()

# %% [markdown]
# To build a linear operator with sparse weights, a weight mask tensor is required.
#
# Let's generate a mask with block size $32\times32$, in which 80% of blocks are empty.

# %%
weight_mask = sparta.testing.block_mask((N, K), block=(32, 32), sparsity=0.8).cuda()
plt.imshow(weight_mask.cpu().numpy())

# %% [markdown]
# Create a ```sparta.nn.SparseLinear``` operator using the dense operator and the weight mask.
#
# Next, tune the sparse operator using a sample input (to determine the shape). This step may take ten minutes.

# %%
x = torch.rand((M, K)).cuda()
sparse_linear = sparta.nn.SparseLinear(dense_linear, weight_mask=weight_mask)
sparta.nn.tune(sparse_linear, sample_inputs=[x])
# Out:
# [2022-09-13 00:21:14] Grid initialized, size: (2×3×3×3×2×2×2) = 432
# ==================== Tuning ====================
# #0: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 2.950045 ms
# #1: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 2.947344 ms
# #2: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 4.75807 ms
# #3: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 4.452179 ms
# #4: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 4.083133 ms
# #5: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 4.070947 ms
# #6: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 8.106599 ms
# #7: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 8.103478 ms
# #8: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 3.67121 ms
# #9: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 3.680218 ms
# #10: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 6.346736 ms
# #11: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 6.371069 ms
# #12: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 5.802361 ms
# #13: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 5.927523 ms
# #14: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# An error occured
# #15: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# An error occured
# #16: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 9.716215 ms
# #17: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 9.610544 ms
# #18: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# An error occured
# #19: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# An error occured
# #20: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# An error occured
# #21: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# An error occured
# #22: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# An error occured
# #23: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# An error occured
# #24: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 2.035072 ms
# #25: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 2.059101 ms
# #26: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 2.604982 ms
# #27: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 2.600058 ms
# #28: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 2.37768 ms
# #29: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 2.381568 ms
# #30: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 4.62881 ms
# #31: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 4.244525 ms
# #32: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 1.947335 ms
# #33: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 1.95383 ms
# #34: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 3.388733 ms
# #35: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 3.18489 ms
# #36: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 2.860995 ms
# #37: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 2.934551 ms
# #38: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 6.127114 ms
# #39: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 6.408368 ms
# #40: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 5.08409 ms
# #41: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 5.079366 ms
# #42: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 9.632704 ms
# #43: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 9.721705 ms
# #44: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 9.006639 ms
# #45: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 9.000387 ms
# #46: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# An error occured
# #47: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# An error occured
# #48: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 2.618896 ms
# #49: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 2.637469 ms
# #50: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 2.829738 ms
# #51: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 2.829299 ms
# #52: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 2.731014 ms
# #53: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 2.806221 ms
# #54: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 4.181277 ms
# #55: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 3.829283 ms
# #56: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 3.284438 ms
# #57: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 3.287703 ms
# #58: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 3.515165 ms
# #59: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 3.47424 ms
# #60: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 3.390358 ms
# #61: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 16, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency:
{'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 5.376864 ms
# #164: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 4.539936 ms
# #165: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 4.454349 ms
# #166: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 15.441504 ms
# #167: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 16, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 15.172058 ms
# #168: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 1.465821 ms
# #169: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 1.466883 ms
# #170: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 1.648221 ms
# #171: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 1.653686 ms
# #172: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 1.490525 ms
# #173: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 1.48888 ms
# #174: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 1.918922 ms
# #175: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 1.924567 ms
# #176: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 1.176333 ms
# #177: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 1.302269 ms
# #178: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 1.434016 ms
# #179: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 1.454074 ms
# #180: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 1.200253 ms
# #181: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 1.204442 ms
# #182: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 1.627885 ms
# #183: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 1.629654 ms
# #184: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 3.026707 ms
# #185: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 2.967834 ms
# #186: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 3.433155 ms
# #187: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 3.017894 ms
# #188: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 2.608855 ms
# #189: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 2.581696 ms
# #190: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 9.060202 ms
# #191: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 9.122826 ms
# #192: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 1.730912 ms
# #193: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 1.736589 ms
# #194: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 1.6588 ms
# #195: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 1.660301 ms
# #196: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 1.587693 ms
# #197: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 1.588461 ms
# #198: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 1.711766 ms
# #199: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 16, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 1.709056 ms
# #200: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 1.753424 ms
# #201: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 1.749501 ms
# #202: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 1.673475 ms
# #203: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 1.691603 ms
# #204: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 1.708784 ms
# #205: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 1.712691 ms
# #206: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 2.051923 ms
# #207: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 1.981606 ms
# #208: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 4.157565 ms
# #209: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 3.844749 ms
# #210: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 3.466595 ms
# #211: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 3.503321 ms
# #212: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 3.131766 ms
# #213: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 3.152771 ms
# #214: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 4}}
# Latency: 10.542353 ms
# #215: {'bc9435b6': {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 64, 'BLOCK_SIZE_K_VALUE': 64, 'THREAD_SIZE_M_VALUE': 8, 'THREAD_SIZE_N_VALUE': 8, 'THREAD_SIZE_K_VALUE': 8}}
# Latency: 10.530362 ms
# #216: {'bc9435b6': {'_name': 'openai'}}
# Latency: 2.154 ms
# [2022-09-13 00:30:20] Search space has been fully explored
# Minimum latency: 1.176333 ms
# Best config: {'_name': 'sparta', 'BLOCK_SIZE_M_VALUE': 64, 'BLOCK_SIZE_N_VALUE': 32, 'BLOCK_SIZE_K_VALUE': 32, 'THREAD_SIZE_M_VALUE': 4, 'THREAD_SIZE_N_VALUE': 4, 'THREAD_SIZE_K_VALUE': 4}

# %% [markdown]
# Let's check whether the sparse operator works correctly.

# %%
sparse_weight = dense_linear.weight * weight_mask
dense_linear.load_state_dict(dict(weight=sparse_weight, bias=dense_linear.bias))
torch.testing.assert_close(sparse_linear(x), dense_linear(x))

# %% [markdown]
# Finally, take a look at how much time can be saved by using the sparse linear operator!

# %%
dense_latency = sparta.testing.test_latency(dense_linear, inputs=[x])
print(f'Dense linear operator latency: {dense_latency} ms')
sparse_latency = sparta.testing.test_latency(sparse_linear, inputs=[x])
print(f'Sparse linear operator latency: {sparse_latency} ms')
# Out:
# Dense linear operator latency: 2.66905078125 ms
# Sparse linear operator latency: 1.1995408935546874 ms
